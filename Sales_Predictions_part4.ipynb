# %% [markdown]
# <a href="https://colab.research.google.com/github/Walt1231/Sales_Predictions-/blob/main/Sales_Predictions_part4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
filename = '/content/sales_predictions.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
#1) How many rows and columns?
df.shape
# Out:
# (8523, 12)

# %%
#2) What are the datatypes of each variable?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#3) Are there duplicates? If so, drop any duplicates.


df.duplicated().sum()
# Out:
# 0

# %%
#4) Identify missing values.
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#5) Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).
ave_weight = df['Item_Weight'].mean()
ave_weight
# Out:
# 12.857645184136183

# %%
df['Item_Weight'].fillna(ave_weight, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
del df['Outlet_Size']
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 11 columns]

# %%
#6) Confirm that there are no missing values after addressing them.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %%
#7) Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content'].replace({'reg':'Regular','low fat':'Low Fat','LF':'Low Fat'}, inplace=True)
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
#8) For any numerical columns, obtain the summary statistics of each (min, max, mean)
df[['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales']].describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  8523.000000      8523.000000  8523.000000        8523.000000
# mean     12.857645         0.066132   140.992782        2181.288914
# std       4.226124         0.051598    62.275067        1706.499616
# min       4.555000         0.000000    31.290000          33.290000
# 25%       9.310000         0.026989    93.826500         834.247400
# 50%      12.857645         0.053931   143.012800        1794.331000
# 75%      16.000000         0.094585   185.643700        3101.296400
# max      21.350000         0.328391   266.888400       13086.964800

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df[['Item_Weight','Item_MRP','Item_Visibility','Item_Outlet_Sales']].hist();

# %%
df.boxplot(['Item_MRP','Item_Outlet_Sales']);

# %%
df_Corr = df[['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales']]

# %%
corr = df_Corr.corr()

# %%
sns.heatmap(corr, cmap='Blues',annot=True);

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 11 columns]

# %%
corr_df = df.corr() 
plt.figure(figsize=(20,15))
sns.heatmap(corr_df, cmap='Blues',annot=True);

# %%
df.hist(figsize=[20, 10]);

# %%
df.plot(kind='box', subplots=True, layout=(3,2),figsize=[20, 10])
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.scatter(df['Outlet_Establishment_Year']-0.2,df['Item_MRP'],c='k',label = 'MRP')
plt.scatter(df['Outlet_Establishment_Year']+0.2,df['Item_Outlet_Sales'],c='b',label = 'Outlet Sale')
plt.legend(loc='lower right',fontsize=15)
plt.xlabel('Establish Year', fontsize=25)
plt.ylabel('Prices',fontsize=25)
plt.title('Compare MRP vs Outlet Sale',fontsize=25)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(c = 'g')
plt.show()

# %%
df[['Item_MRP', 'Item_Outlet_Sales']].plot.hist(alpha=0.5, figsize=(15,10));

# %%
plt.figure(figsize=(18,18))
bar = sns.barplot(x='Item_Outlet_Sales',y='Item_Type', data=df, hue='Item_Fat_Content');
bar.set_xlabel('Outlet Sale Price',fontsize = 20, );
bar.set_ylabel('Item Type',fontsize = 20 );
bar.set_title('Average Outlet Sale Price of Different Type',fontsize = 25)
plt.show()
